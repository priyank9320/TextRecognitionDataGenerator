# %%
# !pip3 install -r requirements.txt

# %%
from trdg.generators import (
    GeneratorFromDict,
    GeneratorFromRandom,
    GeneratorFromStrings,
    GeneratorFromWikipedia,
)
import random
# Out:
# Missing modules for handwritten text generation.

# %%
# to avoid the errors with Pillow
import PIL.Image
if not hasattr(PIL.Image, 'Resampling'):  # Pillow<9.0
    PIL.Image.Resampling = PIL.Image
# Now PIL.Image.Resampling.BICUBIC is always recognized.

# %%
# NOTES
# generator = GeneratorFromRandom(
        # count=2, # decides the number of samples it will generate
        # length = 3, # use max 3 for random english
        # allow_variable = True, # enables variable number of words with max equal to "length" variable
        # use_letters = True,
        # use_numbers = True, # not working for chinese
        # use_symbols = True, # not working for chinese
        # fonts: List[str] = [],
        # language= "en",
        # size = 128, # suize of the image, 128 is a very good size
        # skewing_angle = 5, # keep max 5 i think
        # random_skew = True,
        # blur = 1, # keep max 1, very high blurring effect
        # random_blur = True,
        # background_type = 2, # 0,1,2 three backgrounds
        # distorsion_type = 1, # maybe just use 1
        # distorsion_orientation = 0, # maybe just use 0
        # is_handwritten = True, # install the other requirements file and use tensorflow to use this
        # width: int = -1, # fixes the width for each image, if -ve then auto adjusts
        # alignment = 10, # no significant change
        # text_color: str = "#282828", # dont change
        # orientation: int = 0, # dont change, we need to build MVP only
        # space_width = 5.0, # space between words, float value, can increase it upto 5.0
        # character_spacing = 0, # not very strong change maybe ignore as we need just mvp
        # margins = (5, 5, 5, 50), # adds the extra empty space in the image maybe use values between 5 to 30
        # fit  = True, # probably fits the text in image
        # output_mask  = True, # ignore 
        # word_split: bool = False,
        # image_dir: str = os.path.join(
        #     "..", os.path.split(os.path.realpath(__file__))[0], "images"
        # ),
        # stroke_width = 2, # values 0 to 2 are sufficient, decides width of the linesr
    )
# Out:
#   Cell In[3], line 34
#     )
#     ^
# IndentationError: unexpected indent

# %%
# final code to get wikipedia text
generator = GeneratorFromWikipedia(
        #language=random.choice(["en","cn"]),
        #length = 4,
        max_sentence_length = 4, # max number of words in a sentence
        #allow_variable = True,
        # word_split=True,
        size = 128,
        skewing_angle = 5, # keep max 5 i think
        random_skew = True,
        blur = 1, # keep max 1, very high blurring effect
        random_blur = True,
        background_type = random.randint(0,2), # 0,1,2 three backgrounds
        distorsion_type = random.randint(0,1), # maybe just use 1
        #is_handwritten = random.choice([True,False]), # install the other requirements file and use tensorflow to use this
        space_width = random.uniform(0.0,3.0), # space between words, float value, can increase it upto 5.0
        margins = (  random.randint(0,15), random.randint(0,15), random.randint(0,15), random.randint(0,15)  ), # adds the extra empty space in the image maybe use values between 5 to 30
        stroke_width = random.randint(0,2),
        )
    
    
for img, lbl in generator:
    print(lbl)
    display(img)
    pass
# Out:
# Guy
# <PIL.Image.Image image mode=RGB size=155x128 at 0x7F265B6B8220>
# Mason) for dissociative identity
# <PIL.Image.Image image mode=RGB size=1097x128 at 0x7F260E3B1460>
# United States
# <PIL.Image.Image image mode=RGB size=466x128 at 0x7F260E3B19A0>
# was an Indian
# <PIL.Image.Image image mode=RGB size=603x128 at 0x7F260E3B1640>
# the
# <PIL.Image.Image image mode=RGB size=145x128 at 0x7F260E3B1A30>
# by the
# <PIL.Image.Image image mode=RGB size=299x128 at 0x7F260E33EF70>
# eastern Poland
# <PIL.Image.Image image mode=RGB size=547x128 at 0x7F260E33ECA0>
# (szlachta) in
# <PIL.Image.Image image mode=RGB size=379x128 at 0x7F260E3B1100>
# of
# <PIL.Image.Image image mode=RGB size=94x128 at 0x7F260E3B19A0>
# extinct genus of
# <PIL.Image.Image image mode=RGB size=317x128 at 0x7F260E3B1B50>
# Gammaproteobacteria
# <PIL.Image.Image image mode=RGB size=672x128 at 0x7F260E3B1100>
# siege of
# <PIL.Image.Image image mode=RGB size=270x128 at 0x7F260E3B1370>
# Chile
# ...

# %%
# final code to get chinese and english random text
img, lbl = next(
    GeneratorFromRandom(
        language=random.choice(["en","cn"]),
        length = 4,
        allow_variable = True,
        size = 128,
        skewing_angle = 5, # keep max 5 i think
        random_skew = True,
        blur = 1, # keep max 1, very high blurring effect
        random_blur = True,
        background_type = random.randint(0,2), # 0,1,2 three backgrounds
        distorsion_type = random.randint(0,1), # maybe just use 1
        #is_handwritten = random.choice([True,False]), # install the other requirements file and use tensorflow to use this
        space_width = random.uniform(0.0,3.0), # space between words, float value, can increase it upto 5.0
        margins = (  random.randint(0,15), random.randint(0,15), random.randint(0,15), random.randint(0,15)  ), # adds the extra empty space in the image maybe use values between 5 to 30
        stroke_width = random.randint(0,2),
        )
    
    )
print(lbl)
display(img)
